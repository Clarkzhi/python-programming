# %%
import pandas as pd

# %%
data = pd.read_csv('homicide.csv')

# %%
data.head()
# Out:
#    -79.2186508  43.8065376  1055  GO-2016215657  2016  D42     Other  \
# 0   -79.218651   43.806538  1056  GO-2016215657  2016  D42     Other
# 1   -79.570419   43.755985  1057  GO-2017137133  2017  D31  Shooting
# 2   -79.515823   43.612087  1058  GO-2017163412  2017  D22     Other
# 3   -79.371079   43.651608  1059  GO-2017186988  2017  D51  Shooting
# 4   -79.362335   43.662972  1060  GO-2017189239  2017  D51  Shooting
#
#    2016-02-05T05:00:00.000Z  132                             Malvern (132)  \
# 0  2016-02-05T05:00:00.000Z  132                             Malvern (132)
# 1  2017-01-23T05:00:00.000Z   21                        Humber Summit (21)
# 2  2017-01-26T05:00:00.000Z   17  Mimico (includes Humber Bay Shores) (17)
# 3  2017-01-30T05:00:00.000Z   73                            Moss Park (73)
# 4  2017-01-30T05:00:00.000Z   71      Cabbagetown-South St.James Town (71)
#
#    43.8065376.1  -79.2186508.1  945
# 0     43.806538     -79.218651  946
# ...
